# %% [markdown]
# #### FR0012993103-5

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "hf4w7RgbS78jDgZdB5D2Fj"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("5_bloomberg.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "1BeCiNGINsMGVehDLh3B3h"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("5_bondvision.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "Og4VjT3aUgAStBjpA631Sf"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("5_mts.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "BfQmH9XrAOzhAgwQToMqGj"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("5_tradeweb.csv", "w")
file.write(result)
file.close()

# %% [markdown]
# #### 7TY9  ---6

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "tda0ldtRttrVv3IRwSnwJI"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("6_bloomberg.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "T1cQYtpxxEEkOVQ9hMUzNi"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("6_bondvision.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "qVQyRcWZAtSHGByoqHLsnc"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("6_mts.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "r20BO0XgJjnGWseoFRg6HI"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("6_tradeweb.csv", "w")
file.write(result)
file.close()

# %% [markdown]
# #### 6067 -----7

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "sYGaFBVRjHa7Bf0cx2ZRng"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("7_bloomberg.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "G2kuBf89evGI0tUOIW8L3s"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("7_bondvision.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "iUlqF2zpXNWEeHB10y3TmK"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("7_mts.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "S5Ui3Lz8mjwdUVKItYV9QC"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("7_tradeweb.csv", "w")
file.write(result)
file.close()

# %% [markdown]
# #### 2WK3 ----8

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "3oTmNYGynzHbIs0NAYBavg"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("8_bloomberg.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "FOV1c1nlbER2X4HB0L7q9C"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("8_bondvision.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "BhVa5N66WRchCZisE0dol8"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("8_mts.csv", "w")
file.write(result)
file.close()

# %%
import os
import looker_sdk
os.environ["LOOKERSDK_BASE_URL"] = "https://propellantdigital.cloud.looker.com"
os.environ["LOOKERSDK_CLIENT_ID"] = "vxnbWYrhnNthXtDdtRfr"
os.environ["LOOKERSDK_CLIENT_SECRET"] = "y4J9S9yTkmKj3C2FjxgF9NCs"
sdk = looker_sdk.init40()
# posttrade rts2
explore_id = "HXgm2ns9tRfx6sfSlfSaG4"
explore_query = sdk.query_for_slug(slug=explore_id)
#print("Query: " + str(explore_query4j9Vy2JkU7f45j8z9JJRZe
result = sdk.run_query(
 explore_query.id,
 result_format="csv",
 )
file = open("8_tradeweb.csv", "w")
file.write(result)
file.close()
